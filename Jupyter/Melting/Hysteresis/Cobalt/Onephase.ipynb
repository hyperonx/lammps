# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline
sns.set()
plt.rcParams['figure.figsize'] = [11, 7]

# %%
columns =['step', 'temp','press','vol','ke','pe','density']

# %%
file = "one_phase.txt"

# %%
df = pd.read_csv(file, header=None, skiprows = 1, delimiter ="\s+" , names = columns)

# %%
plt.plot(df['temp'], df["vol"], color ="r", marker ="x", label="Heating")
# plt.plot(temp_cool, vol_cool, color ="b", marker ="x",label="Cooling")
# plt.xlim([0,2800])
# plt.title('$Melting \;Temperature=2250+1050-\sqrt{2250*1050} = 1762.98 K$')
# # plt.title(f'$\mu_P={df.iloc[df["Cohesive Energy"]]["a"]},E_c={df["Cohesive Energy"]}$')
# plt.xticks(range(0,2800,100),rotation=90)
plt.ylabel("Volume")
plt.xlabel("Temperature")
# plt.tight_layout()
plt.legend()
# plt.savefig("melting.png",dpi=300)
# plt.xticks(rotation=90)

plt.show()
